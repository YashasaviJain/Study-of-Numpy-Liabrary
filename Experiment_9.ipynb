# %% [markdown]
# *  Name-Yashasavi Jain
#
# *  PRN-25070123127
#
# *  Batch-B3
#
# *  Aim-Study of Numpy Laibrary

# %%
# Declaration of Numpy
import numpy as np
a = np.array([1,10,20,30,40,50,500])
b = np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
display(a.dtype)
print(b * 2)
print(a + 5)
# Out:
# [  1  10  20  30  40  50 500]
# [[1 2 3]
#  [4 5 6]]
# dtype('int64')
# [[ 2  4  6]
#  [ 8 10 12]]
# [  6  15  25  35  45  55 505]

# %%
# Dimension of Array
print(a.ndim)
print(b.ndim)
# Out:
# 1
# 2

# %%
print(a.shape)
# Out:
# (7,)

# %%
print(b.shape)
# Out:
# (2, 3)

# %%
print(a.dtype)
# Out:
# int64

# %%
# In-Built functions using Numpy
print(np.zeros((2,3)))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(np.ones((3,3)))
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
print(np.eye((3)))
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
print(np.arange(1,11,2))
# Out:
# [1 3 5 7 9]

# %%
print(np.linspace(0,1,4))
# Out:
# [0.         0.33333333 0.66666667 1.        ]

# %%
print(np.mean(a))
# Out:
# 93.0

# %%
print(np.median(a))
# Out:
# 30.0

# %%
print(np.max(a))
# Out:
# 500

# %%
print(np.sum(a))
# Out:
# 651

# %%
print(np.min(a))
# Out:
# 1
